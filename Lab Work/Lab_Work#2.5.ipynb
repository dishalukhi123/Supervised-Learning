# %% [markdown]
# ### QUEST 01 — Overall Model Significance — The F-Test
# #### Q1. Why F-test first?
#
# Before testing individual predictors, we first check whether the entire model explains any variation in the target variable.
#
# **Null Hypothesis (H₀)**
# H0:β1=β2=⋯=βk=0
#
# All predictor coefficients are zero.
#
# **Alternative Hypothesis (H₁)**
# H1:At least one βj=0
#
# At least one predictor significantly contributes to predicting y.
#
# **Interpretation**
# - H₀: Model is no better than predicting the mean.
# - H₁: Model contains useful predictive information.

# %% [markdown]
# #### Q2. F-statistic Formula
# Formula
# F=SSR/k/SSE/(n−k−1)
#
# or
#
# F=
# MSE/MSR
# 	​
# Mean Square Regression (MSR)
# MSR=SSR/k
# 	​
# Measures explained variation per predictor.
#
# Mean Square Error (MSE)
# MSE=SSE/n−k−1
#
# Measures unexplained variation per residual degree of freedom.
#
# **Why Large F is Good**
#
# If
#
# MSR>>MSE
#
# then predictors explain much more variation than random noise.
#
# A large F-statistic indicates the model performs better than a mean-only baseline model.

# %% [markdown]
# #### Q3. Degrees of Freedom
# **Regression Sum of Squares (SSR)**
# dfSSR=k
#
# One degree of freedom for each predictor.
#
# **Error Sum of Squares (SSE)**
# df.SSE=n−k−1
#
# **Why "-1"?**
#
# One degree of freedom is used to estimate the intercept β0.
#
# Therefore:
#
# n−(k+1)
#
# degrees remain for estimating error.
#
# **Why Intercept Does Not Appear in SSR df?**
#
# SSR measures variation explained only by predictors.
#
# The intercept is treated as a baseline constant, not a predictor.

# %% [markdown]
# #### Q4. Worked Example
# **Given**
# n=20
# k=3
# SST=500
# SSR=380
#
# **Step 1: Compute SSE**
# Using
#
# SST=SSR+SSE
# 500=380+SSE
# SSE=120
#
# **Step 2: Compute MSR**
# MSR=SSR/k
# MSR=380/3
# MSR=126.67
#
# **Step 3: Compute MSE**
# MSE=SSE/n−k−1
# MSE=120/20−3−1
# MSE=120/16
# MSE=7.5
#
# **Step 4: Compute F-statistic**
# F=MSR/MSE
# F=126.67/7.5
# F=16.89
#
# **Result**
# F=16.89
# 	​
#
# ###### Interpretation
#
# The model explains substantially more variation than random noise and appears statistically significant.
#
# #### Q5. F-Test vs R²
# Compute R²
#     R2=SSR/SST
#
# 	​R2=380/500
# 	​
#     R2=0.76
#
# Interpretation
# The model explains:
#
#     76%
#
# of variation in y.
#
# **Why R² Alone Is Not Enough**
#
# A high R² does not tell us whether the relationship is statistically significant.
#
# R² only measures fit.
#
# The F-test additionally considers:
#
# - Sample size (n)
# - Number of predictors (k)
# - Random error
#
# and determines whether the observed fit could have occurred by chance.
#
#
# #### Q6. Decision Rule
# Given
# Critical value:
# Fcritical(3,16)=3.24
#
# Calculated value:
# F=16.89
#
# Compare
# 16.89>3.24
#
# Decision
# Reject H₀.
#
# **Conclusion**
#
# The overall model is statistically significant.
#
# Plain English Interpretation
#
# The predictors collectively explain a meaningful amount of variation in the target variable, and the model performs significantly better than simply predicting the average value for everyone.
#
# Quick Viva Revision
# F-Test Hypotheses
# H0:β1=β2=⋯=βk=0
#
# H1:At least one βj=0
#
# F Formula
# F=SSR/k/SSE/(n−k−1)
# 	​
# Degrees of Freedom
# dfSSR=k
# dfSSE=n−k−1
#
# Worked Example Results
# SSE=120
# MSR=126.67
# MSE=7.5
# F=16.89
# R2=0.76
#
# Final Decision
# 16.89>3.24
#
# ✅ Reject H₀
# ✅ Overall model is significant.

# %% [markdown]
# ### QUEST 02 — Individual Coefficient Tests (t-Tests for Each βⱼ)
#
# #### Q1. Purpose of Individual t-Tests
#
# The F-test tells us whether the model contains at least one useful predictor.
#
# The t-test identifies which specific predictor contributes significantly to the model.
#
# **Hypotheses for Predictor xj**
# 	​
# **Null Hypothesis**
# H0:βj=0
#
# Predictor xj has no linear effect on y.
#
# **Alternative Hypothesis**
# H1:βj=0
#
# Predictor xj has a significant linear effect on y.
#
#
#
# #### Q2. Standard Error of β^j
# 	​
# **Covariance Matrix of Coefficients**
# Cov(β^)=σ2(X.TX)−1
#
# Since σ2 is unknown, we estimate it using:
# MSE=SSE/n−k−1
# 	​
# Standard Error Formula
# SE(β^j)=MSE×[(X.TX)−1]jj
# 	​
#
# Meaning of Diagonal Elements
#
# The diagonal entries of (X.TX)−1:
# [(X.TX)−1]jj
# 	​
#
# measure the variability of each coefficient estimate.
#
# Large values indicate:
#
# - Less precise coefficient estimates
# - Possible multicollinearity
# - Higher uncertainty
#
# #### Q3. t-Statistic
# **Formula**
# tj=β^j/SE(β^j)
#
# **Degrees of Freedom**
# df=n−k−1
# Why n−k−1?
#
# We estimate:
#
# - k slope coefficients
# - 1 intercept
#
# Total parameters estimated:
#
# k+1
#
# Remaining degrees of freedom:
#
# n−(k+1)
# =n−k−1
#
# Hence the t-distribution uses:
#
# df=n−k−1
#
#
# #### Q4. Worked Example
# Given
# β^1=2.5
# SE(β^1)=0.8
# β^2=0.3
# SE(β^2)=1.2
# n=20
# k=3
#
# Critical value:
#
# t∗=2.120
#
# Compute t1
# t1=2.5/0.8
#
# t1=3.125
#
# Compute t2
# t2=0.3/1.2
#
# t2=0.25
#
# Compare with Critical Value
# Predictor 1
#     ∣3.125∣>2.120
#
# ✅ Significant
#
# Predictor 2
#    ∣0.25∣<2.120
#
# ❌ Not Significant
#
# Conclusion
#
# Predictor x1 is significant.
#
# Predictor x2 is not significant.
#
# #### Q5. Confidence Interval for β1
# Formula
# CI=β^j±t∗SE(β^j)
#
# Substitute Values
# CI=2.5±(2.120)(0.8)
# CI=2.5±1.696
#
# Lower Limit
# 2.5−1.696=0.804
#
# Upper Limit
# 2.5+1.696=4.196
# 95% Confidence Interval
# (0.804,4.196)
# 	​
#
# Plain English Interpretation
#
# The true increase in y associated with a one-unit increase in x1 is likely between 0.804 and 4.196 units.
#
# #### Q6. Dropping Non-Significant Predictors
#
# Suppose:
#
# p=0.78
#
# for predictor x2.
#
# Why Drop It?
#
# Because it contributes little measurable information to predicting y.
#
# Removing it may:
#
# - Simplify the model
# - Reduce complexity
# - Improve interpretability
# - Reduce overfitting

# %% [markdown]
# ### QUEST 03 — Multicollinearity: VIF Diagnosis & Remedy
#
# #### Q1. Define Multicollinearity
# Definition
#
# Multicollinearity occurs when two or more predictor variables are highly correlated with each other.
#
# This means one predictor can be predicted from another predictor.
#
# Mathematically:
#
# x1≈a+bx2
# 	​
# When this happens, it becomes difficult for the regression model to determine the individual effect of each predictor.
#
# Real-World Example
#
# Suppose we build a salary prediction model:
#
# Salary=β0+β1(Experience)+β2(Age)
#
# Usually:
#
# - More age → more experience
# - Less age → less experience
#
# Therefore:
#
# Age≈Experience+Constant
#
# These variables become highly correlated and create multicollinearity.
#
#
# #### Q2. Consequence on β̂
#
# When predictors become highly correlated:
#
# XT.X
#
# becomes nearly singular.
#
# That means its determinant approaches zero.
#
# Effect on (XT.X)−1
# The inverse matrix:
#
# (XT.X)−1
#
# contains very large values.
# Since:
#
# Cov(β^)=σ2(XT.X)−1
#
# large values in (XT.X)−1 increase coefficient variance.
#
# Effect on Standard Errors
# SE(β^j)=MSE[(XT.X)−1]jj
# 	​
# As (XT.X)−1 grows:
#
# SE(β^j)
#
# also grows.
#
# Plain English
#
# The model cannot determine whether x1 or x2 is causing the change in y.
#
# Therefore coefficient estimates become unstable.
#
# #### Q3. Variance Inflation Factor (VIF)
# Formula
# VIFj=1/1−Rj2
#
# where:
# Rj2
# 	​
#
# comes from regressing predictor xj on all remaining predictors.
#
# Interpretation
# VIF = 1
# VIF=1
#
# No multicollinearity.
#
# Predictor is independent of others.
#
# VIF = 5
# VIF=5
#
# Moderate multicollinearity.
#
# Needs monitoring.
#
# VIF = 12
# VIF=12
#
# Severe multicollinearity.
#
# Corrective action is recommended.
#
#
#
# **Common Rule**
# | VIF  | Interpretation   |
# | ---- | ---------------- |
# | 1–5  | Safe             |
# | 5–10 | Moderate concern |
# | >10  | Serious problem  |
#
#
# #### Q4. Compute VIF
# Given
# x1=[2,4,6,8]
# x2=[1,2,3,4]
#
# Observe:
# x1=2x2
#
# Perfect linear relationship.
#
# Auxiliary Regression
#
# Regress:
# x1 on x2
# 	​
# Since prediction is perfect:
#
# R2=1
#
# Compute VIF
# VIF1=1/1−R
#
# Substitute:
#
# VIF1=1/1−1
# VIF1=∞
#
# Interpretation
#
# Perfect multicollinearity exists.
# The OLS inverse:
#
# (XT.X)−1
#
# cannot be computed.
# OLS coefficients are not uniquely estimable.
#
#
# #### Q5. Correlation Matrix vs VIF
# **Given**
# r=0.97
#
# between x1 and x2.
#
# This suggests strong correlation.
#
# **Why Correlation Matrix Is Insufficient**
# Correlation matrix only checks:
#
# xi↔xj
# 	​
#
#
# pairwise relationships.
#
# It cannot detect combined relationships among several predictors.
#
# Example
#
# Suppose:
#
# x3=x1+x2
# 	​
# Then:
# - Pairwise correlations may not appear extreme.
# - Yet strong multicollinearity exists.
#
# What VIF Adds
#
# VIF measures:
# xj
#
# against all other predictors simultaneously.
#
# Therefore VIF captures hidden multicollinearity missed by simple correlations.
#
#
# #### Q6. Remedies for Multicollinearity
# ##### (A) Drop One Predictor
# Example:
#
# - Age
# - Experience
#
# If both provide nearly identical information, remove one.
#
# **Safe When**
# - Variables measure the same concept.
# - Business interpretation remains intact.
#
# ##### (B) Principal Component Analysis (PCA)
#
# Combine correlated predictors into new components.
# Example:
#
# PC1=0.7x1+0.7x2
# 	​
#
# **Advantage**
# Removes multicollinearity.
#
# **Tradeoff**
# Interpretability decreases.
# The new variables no longer have direct business meaning.
#
# ##### (C) Ridge Regression
# Modify the cost function.
#
# **Ordinary Least Squares**
# L(β)=∑(yi−y^i)2
#
# **Ridge Regression**
# L(β)=∑(yi−y^i)2+λ∑βj2
# 	​
# L(β)=∑(yi−y^i)2+λ∑βj2
# 	​
# **Why It Works**
# Ridge effectively replaces:
#
# XT.X
#
# with
#
# X.TX+λI
#
# making the matrix invertible and stabilizing coefficient estimates.
#
# #### Quick Viva Revision
# **Multicollinearity**
#
# High correlation among predictors.
#
# VIF Formula
# VIFj=1/1−Rj2
# 	​
#
# Interpretation
# | VIF | Meaning              |
# | --- | -------------------- |
# | 1   | No multicollinearity |
# | 5   | Moderate             |
# | 10+ | Serious              |
#
#
# x1=[2,4,6,8]
# x2=[1,2,3,4]
# R2=1
# VIF=∞
#
# ### QUEST 04 — Dummy Variables: Encoding Categorical Predictors
#
# #### Q1. Why Dummy Variables?
# Multiple Linear Regression (MLR) requires numerical inputs.
#
# Suppose we have:
# | City      |
# | --------- |
# | Mumbai    |
# | Delhi     |
# | Bangalore |
#
# Encoding them as:
# | City      | Code |
# | --------- | ---- |
# | Mumbai    | 1    |
# | Delhi     | 2    |
# | Bangalore | 3    |
#
# is incorrect because it implies:
#
# Bangalore>Delhi>Mumbai
#
# and assumes equal spacing:
#
# 3−2=2−1
#
# which has no real meaning.
#
# Cities are nominal categories, not numbers.
#
# Therefore we use dummy variables (one-hot encoding).
#
#
# Q2. One-Hot Encoding
#
# For:
#
# City=[Mumbai,Delhi,Bangalore]
#
# Create:
#
# D₁ (Mumbai)
# D
# 1
# 	​
#
# ={
# 1,
# 0,
# 	​
#
# Mumbai
# otherwise
# 	​
#
# D₂ (Delhi)
# D
# 2
# 	​
#
# ={1,0,Delhi
# Bangalore becomes the reference category.
#
# Why Only k−1 Dummies?
#
# For:
#
# k=3
#
# cities:
#
# k−1=2
#
# dummy variables are sufficient.
#
# If:
#
# D1=0,D2=0
#
# then observation automatically belongs to Bangalore.
